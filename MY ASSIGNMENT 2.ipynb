# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
covid19=pd.read_csv('C:/rfiles/covid19_data_mar.csv')

# %%
covid19['age'].describe()
# Out:
# count    265.000000
# mean      53.301887
# std       17.563936
# min        4.000000
# 25%       43.000000
# 50%       55.000000
# 75%       65.000000
# max       89.000000
# Name: age, dtype: float64

# %%
covid19
# Out:
#        id  case_in_country reporting date          location      country  \
# 0     195              NaN      1/27/2020             Hubei        China
# 1     196              NaN      1/27/2020             Hubei        China
# 2     197              NaN      1/27/2020          Shandong        China
# 3     237              1.0      1/15/2020          Kanagawa        Japan
# 4     241              5.0      1/28/2020  Aichi Prefecture        Japan
# ..    ...              ...            ...               ...          ...
# 265   964             93.0      2/27/2020         Hong Kong    Hong Kong
# 266   993              1.0       2/2/2020            Manila  Phillipines
# 267   996              1.0      1/29/2020           Lapland      Finland
# 268  1007             11.0      2/26/2020         Barcelona        Spain
# 269  1031              1.0      1/31/2020         Jonkoping       Sweden
#
#      gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# ...

# %%
covid19.loc[np.isnan(covid['age']), ['age']]= covid['age'].mean()

# %%
covid19['If_onset_approximated'].describe()
# Out:
# count    252.000000
# mean       0.043651
# std        0.204724
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: If_onset_approximated, dtype: float64

# %%
covid19.loc[np.isnan(covid19['If_onset_approximated']), ['If_onset_approximated']]= covid19['If_onset_approximated'].mean()
covid19
# Out:
#        id  case_in_country reporting date          location      country  \
# 0     195              NaN      1/27/2020             Hubei        China
# 1     196              NaN      1/27/2020             Hubei        China
# 2     197              NaN      1/27/2020          Shandong        China
# 3     237              1.0      1/15/2020          Kanagawa        Japan
# 4     241              5.0      1/28/2020  Aichi Prefecture        Japan
# ..    ...              ...            ...               ...          ...
# 265   964             93.0      2/27/2020         Hong Kong    Hong Kong
# 266   993              1.0       2/2/2020            Manila  Phillipines
# 267   996              1.0      1/29/2020           Lapland      Finland
# 268  1007             11.0      2/26/2020         Barcelona        Spain
# 269  1031              1.0      1/31/2020         Jonkoping       Sweden
#
#      gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# ...

# %%
covid19.isnull()
# Out:
#         id  case_in_country  reporting date  location  country  gender    age  \
# 0    False             True           False     False    False   False  False
# 1    False             True           False     False    False   False  False
# 2    False             True           False     False    False   False  False
# 3    False            False           False     False    False   False  False
# 4    False            False           False     False    False   False  False
# ..     ...              ...             ...       ...      ...     ...    ...
# 265  False            False           False     False    False   False  False
# 266  False            False           False     False    False   False  False
# 267  False            False           False     False    False   False  False
# 268  False            False           False     False    False   False  False
# 269  False            False           False     False    False   False  False
#
# ...

# %%
covid19.isnull().any()
# Out:
# id                       False
# case_in_country           True
# reporting date           False
# location                 False
# country                  False
# gender                    True
# age                       True
# symptom_onset             True
# If_onset_approximated    False
# hosp_visit_date           True
# exposure_start            True
# exposure_end              True
# incubationdays           False
# hospitaldays             False
# visiting Wuhan           False
# from Wuhan               False
# death                     True
# recovered                 True
# symptom                  False
# dtype: bool

# %%
covid19=covid19.drop('exposure_start',axis=1)###many nullvalues.
covid19=covid19.drop('death',axis=1)###many nullvalues.
covid19=covid19.drop('death',axis=1)###many nullvalues.
covid19=covid19.drop('exposure_end',axis=1)###many nullvalues.

# %%
covid19
# Out:
#        id  case_in_country reporting date          location      country  \
# 0     195              NaN      1/27/2020             Hubei        China
# 1     196              NaN      1/27/2020             Hubei        China
# 2     197              NaN      1/27/2020          Shandong        China
# 3     237              1.0      1/15/2020          Kanagawa        Japan
# 4     241              5.0      1/28/2020  Aichi Prefecture        Japan
# ..    ...              ...            ...               ...          ...
# 265   964             93.0      2/27/2020         Hong Kong    Hong Kong
# 266   993              1.0       2/2/2020            Manila  Phillipines
# 267   996              1.0      1/29/2020           Lapland      Finland
# 268  1007             11.0      2/26/2020         Barcelona        Spain
# 269  1031              1.0      1/31/2020         Jonkoping       Sweden
#
#      gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# ...

# %%
covid19
# Out:
#        id  case_in_country reporting date          location      country  \
# 0     195              NaN      1/27/2020             Hubei        China
# 1     196              NaN      1/27/2020             Hubei        China
# 2     197              NaN      1/27/2020          Shandong        China
# 3     237              1.0      1/15/2020          Kanagawa        Japan
# 4     241              5.0      1/28/2020  Aichi Prefecture        Japan
# ..    ...              ...            ...               ...          ...
# 265   964             93.0      2/27/2020         Hong Kong    Hong Kong
# 266   993              1.0       2/2/2020            Manila  Phillipines
# 267   996              1.0      1/29/2020           Lapland      Finland
# 268  1007             11.0      2/26/2020         Barcelona        Spain
# 269  1031              1.0      1/31/2020         Jonkoping       Sweden
#
#      gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# ...

# %%
round(100*(covid19.isnull().sum()/len(covid19.index)),2)
# Out:
# id                        0.00
# case_in_country           1.11
# reporting date            0.00
# location                  0.00
# country                   0.00
# gender                    0.37
# age                       1.85
# symptom_onset             6.67
# If_onset_approximated     0.00
# hosp_visit_date          20.74
# incubationdays            0.00
# hospitaldays              0.00
# visiting Wuhan            0.00
# from Wuhan                0.00
# symptom                   0.00
# dtype: float64

# %%
plt.bar(covid19['country'],covid19['age'] )
plt.xlabel("COUNTRY")
plt.ylabel("AGE")
plt.title("COUNTRY VS AGE")
plt.show()

# %%
import seaborn as sns
sns.barplot(y=covid19['country'],x=covid19['age'] )
# Out:
# <AxesSubplot:xlabel='age', ylabel='country'>

# %%
sns.boxplot(covid19['age'])
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(covid19['age'], rug= True,hist=False)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(covid19['age'], rug= True,hist=True)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
covid19['symptom'].describe()
# Out:
# count       270
# unique      108
# top       fever
# freq         73
# Name: symptom, dtype: object

# %%
covid19['symptom'].value_counts()
# Out:
# fever                          73
# fever, cough                   36
# cough                          14
# fever, malaise                  7
# fever, sore throat              6
#                                ..
# sore throat, cough, fever       1
# fever, sore throat, malaise     1
# fatigue, malaise, headache      1
# difficulty breathing            1
# cough with sputum               1
# Name: symptom, Length: 108, dtype: int64

# %%
covid19['case_in_country'].value_counts()
# Out:
# 1.0      13
# 5.0       5
# 25.0      5
# 15.0      5
# 19.0      4
#          ..
# 100.0     1
# 99.0      1
# 98.0      1
# 97.0      1
# 89.0      1
# Name: case_in_country, Length: 167, dtype: int64
